# %%
from utils import *
from queue import Queue
from api import *

# %%
def edge_detector(img):
    lap = cv2.Laplacian(img, cv2.CV_64F)
    lap = np.uint8(np.absolute(lap))
    lap_gray = cv2.cvtColor(lap, cv2.COLOR_RGB2GRAY)
    return lap_gray

# %%
img = read_image('testcase/rgb.jpeg')
show_image(img)
print(img[50, 200])
# Out:
# [179 173 154]

# %%
print(get_people(img.copy(), 150))
# Out:
# [((157, 630), array([175.63414634, 173.35772358, 168.14227642])), ((472, 585), array([178.25301205, 185.36746988, 161.30722892])), ((663, 197), array([168.8563135 , 167.13497823, 164.91727141]))]
