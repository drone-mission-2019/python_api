# %%
from runnable.utils import *
from queue import Queue
from runnable.api import *

# %%
def edge_detector(img):
    lap = cv2.Laplacian(img, cv2.CV_64F)
    lap = np.uint8(np.absolute(lap))
    lap_gray = cv2.cvtColor(lap, cv2.COLOR_RGB2GRAY)
    return lap_gray

# %%
img = read_image('task_3_2/0zed0.jpg')
show_image(img)
print(img[50, 200])
# Out:
# [197 188 179]

# %%
print(get_people(img.copy(), 150))
# Out:
# [((188, 658), array([136.64705882, 170.66666667, 136.26470588])), ((483, 624), array([135.99038462, 167.52884615, 132.74038462])), ((40, 527), array([189.97090909, 129.12      , 128.05090909])), ((1188, 504), array([136.06018519, 177.23148148, 138.79166667]))]
