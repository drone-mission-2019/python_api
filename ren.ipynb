# %%
from runnable.utils import *
from queue import Queue
from runnable.api import *

# %%
def edge_detector(img):
    lap = cv2.Laplacian(img, cv2.CV_64F)
    lap = np.uint8(np.absolute(lap))
    lap_gray = cv2.cvtColor(lap, cv2.COLOR_RGB2GRAY)
    return lap_gray

# %%
img = read_image('task_3_2/5zed0.jpg')
show_image(img)
print(img[50, 200])
# Out:
# [180 178 168]

# %%
print(get_people(img.copy(), 150))
# Out:
# [((138, 585), array([102.05970149, 145.91044776, 186.79850746])), ((288, 460), array([176.83783784, 175.25225225, 161.79279279])), ((518, 433), array([175.09345794, 176.25233645, 163.48598131])), ((1119, 360), array([101.0877193 , 100.39473684,  99.32894737])), ((821, 111), array([178.15258216, 171.70187793, 158.91314554]))]
