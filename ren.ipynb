# %%
from runnable.utils import *
from queue import Queue
from runnable.api import *

# %%
def edge_detector(img):
    lap = cv2.Laplacian(img, cv2.CV_64F)
    lap = np.uint8(np.absolute(lap))
    lap_gray = cv2.cvtColor(lap, cv2.COLOR_RGB2GRAY)
    return lap_gray

# %%
img = read_image('task_3_2/2302.jpeg')
show_image(img)
print(img[50, 200])
# Out:
# [180 178 168]

# %%
print(get_people(img.copy(), 150))
# Out:
# [((1120, 363), array([107.28378378, 106.73873874, 105.55855856])), ((796, 67), array([109.72932331, 108.68421053, 106.88721805]))]
